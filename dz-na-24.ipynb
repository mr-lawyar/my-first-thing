# %%
# %pip install -r requirements.txt -q
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("chile_north.txt")
dist = data[:, 0]     # відстань від жолоба вглиб континенту, км
depth = data[:, 1]    # глибина, км
lat = data[:, 2]      # широта
lon = data[:, 3]      # довгота

# %% [markdown]
# Задача №1

# %%
k, b = np.polyfit(dist, depth, 1)
print(k)
print(b)

# у мене не вийшло підставити 400 замість dist
# Out:
# 0.32432172052586233
# 1.4803626318498213

# %% [markdown]
# Задача №2

# %%
under_50 = np.sum(depth < 50)
print(under_50)

more_than_100 = np.sum(depth > 100)
print(more_than_100)
# Out:
# 695
# 1665

# %% [markdown]
# Задача №3

# %%
data = np.loadtxt("chile_south.txt")
dist = data[:, 0]     # відстань від жолоба вглиб континенту, км
depth = data[:, 1]    # глибина, км
lat = data[:, 2]      # широта
lon = data[:, 3] 

# треба запустити цей код, щоб працювала задача 3

# %%
k, b = np.polyfit(dist, depth, 1)
print(k)
print(b)
# Out:
# 0.2602342694063177
# 35.188007378530976
