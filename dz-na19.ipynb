# %%
# %pip install -r requirements.txt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
r_earth = 6378 # km, from google
r_star = r_earth * 109

print(r_star) # the radius of the star


# я не зрозумів завдання...
# Out:
# 695202

# %%
data = np.loadtxt("tres2_lightcurve.txt")
t = data[:, 0]
f = data[:, 1]

# %%
P = 2.47
all_time = t[-1] - t[0] 
# я випадково увімкнув ШІ яке допомагає з кодом, я сам не знаю, що це значить "t[-1] - t[0]" 
# (я не знаю як його вимкнути, вибачте)
# вона увімкнулась тільки в цій задачі
full_turns = all_time / P

print(full_turns)


# надіюсь, що правильно вивело значення
# Out:
# 595.328947368421

# %%
t_of_mistake = 14 # хвилин
all_mistakes = 14 * full_turns / 60 / 24 # діб

print(all_mistakes)

# не зрозумів про "вгадати" коли відбудеться наступний зсув у завданні
# Out:
# 5.787920321637427
